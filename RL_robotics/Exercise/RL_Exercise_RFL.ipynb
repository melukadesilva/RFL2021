# %%
# !pip install Box2D
# !pip install box2d-py
# !pip install gym[all]
# !pip install gym[Box_2D]

# %% [markdown]
# ## Exercise:
# ### Take the code available at: https://github.com/lazavgeridis/LunarLander-v2.git
# ### Explain the following for both SARSA and Q-Learning
# ### 1. Algorithm + policy selection method
# ### 2. Adaptation of the state space of the LunarLander
# ### Provide your explanations as a documentation of the code
# ### Deadline: 4th of February
# ### Submit the Jupyter notebook per Email.

# %%
environment = gym.make("LunarLander-v2")
sarsa_lander(environment, 10000, 0.99, 1e-3, 1e-2)
# Out:
# Last 100 episodes mean reward: -141.3
# Last 100 episodes mean reward: -124.1
# Last 100 episodes mean reward: -126.7
# Last 100 episodes mean reward: -157.4
#
# Episode finished after 223 timesteps
# Episode 500: Total Return = -305.0043971110453
# Total keys in q_states dictionary = 7713
# Last 100 episodes mean reward: -154.7
# Last 100 episodes mean reward: -163.5
# Last 100 episodes mean reward: -181.4
# Last 100 episodes mean reward: -177.3
# Last 100 episodes mean reward: -174.6
#
# Episode finished after 131 timesteps
# Episode 1000: Total Return = -45.485632203409665
# Total keys in q_states dictionary = 10143
# Last 100 episodes mean reward: -185.4
# Last 100 episodes mean reward: -184.9
# Last 100 episodes mean reward: -165.3
# Last 100 episodes mean reward: -143.9
# Last 100 episodes mean reward: -154.8
#
# Episode finished after 133 timesteps
# Episode 1500: Total Return = -64.51246159118438
# Total keys in q_states dictionary = 11604
# ...

# %%
qlearning_lander(environment, 10000, 0.99, 1e-3, 1e-2)
# Out:
# Last 100 episodes mean reward: -161.2
# Last 100 episodes mean reward: -142.6
# Last 100 episodes mean reward: -116.0
# Last 100 episodes mean reward: -139.9
#
# Episode finished after 237 timesteps
# Episode 500: Total Return = -99.27904895070377
# Total keys in q_states dictionary = 8476
# Last 100 episodes mean reward: -160.8
# Last 100 episodes mean reward: -157.1
# Last 100 episodes mean reward: -184.2
# Last 100 episodes mean reward: -175.6
# Last 100 episodes mean reward: -175.2
#
# Episode finished after 124 timesteps
# Episode 1000: Total Return = -64.28447257797328
# Total keys in q_states dictionary = 10072
# Last 100 episodes mean reward: -191.5
# Last 100 episodes mean reward: -166.4
# Last 100 episodes mean reward: -164.6
# Last 100 episodes mean reward: -159.1
# Last 100 episodes mean reward: -164.2
#
# Episode finished after 163 timesteps
# Episode 1500: Total Return = -29.86568818638132
# Total keys in q_states dictionary = 11076
# ...
